# %%
#Badr SAMAD
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv('data_cleaned.csv')

# %%
data.head()
# Out:
#                    Job Title              Salary Estimate  \
# 0             Data Scientist   $53K-$91K (Glassdoor est.)
# 1  Healthcare Data Scientist  $63K-$112K (Glassdoor est.)
# 2             Data Scientist   $80K-$90K (Glassdoor est.)
# 3             Data Scientist   $56K-$97K (Glassdoor est.)
# 4             Data Scientist  $86K-$143K (Glassdoor est.)
#
#                                      Job Description  Rating  \
# 0  Data Scientist\nLocation: Albuquerque, NM\nEdu...     3.8
# 1  What You Will Do:\n\nI. General Summary\n\nThe...     3.4
# 2  KnowBe4, Inc. is a high growth information sec...     4.8
# 3  *Organization and Job ID**\nJob ID: 310709\n\n...     3.8
# 4  Data Scientist\nAffinity Solutions / Marketing...     2.9
#
#                                  Company Name         Location  \
# 0                      Tecolote Research\n3.8  Albuquerque, NM
# 1  University of Maryland Medical System\n3.4    Linthicum, MD
# ...

# %%
data.columns
# Out:
# Index(['Job Title', 'Salary Estimate', 'Job Description', 'Rating',
#        'Company Name', 'Location', 'Headquarters', 'Size', 'Founded',
#        'Type of ownership', 'Industry', 'Sector', 'Revenue', 'Competitors',
#        'hourly', 'employer_provided', 'minimum_salary', 'maximum_salary',
#        'average_salary', 'company_name_txt', 'job_state', 'same_state',
#        'Age of the company', 'Python', 'R_studio', 'spark', 'aws', 'excel'],
#       dtype='object')

# %%
def title_simplifier(title):
    if 'data scientist' in title.lower():
        return 'data scientist'
    elif 'data engineer' in title.lower():
        return 'data engineer'
    elif 'analyst' in title.lower():
        return 'analyst'
    elif 'machine learning' in title.lower():
        return 'mle'
    elif 'manager' in title.lower():
        return 'manager'
    elif 'director' in title.lower():
        return 'director'
    else:
        return 'na'
    
def seniority(title):
    if 'sr' in title.lower() or 'senior' in title.lower() or 'sr' in title.lower() or 'lead' in title.lower() or 'principal' in title.lower():
            return 'senior'
    elif 'jr' in title.lower() or 'jr.' in title.lower():
        return 'jr'
    else:
        return 'na'

# %%
data['title_simplified'] = data['Job Title'].apply(title_simplifier)

# %%
data.head()
# Out:
#                    Job Title              Salary Estimate  \
# 0             Data Scientist   $53K-$91K (Glassdoor est.)
# 1  Healthcare Data Scientist  $63K-$112K (Glassdoor est.)
# 2             Data Scientist   $80K-$90K (Glassdoor est.)
# 3             Data Scientist   $56K-$97K (Glassdoor est.)
# 4             Data Scientist  $86K-$143K (Glassdoor est.)
#
#                                      Job Description  Rating  \
# 0  Data Scientist\nLocation: Albuquerque, NM\nEdu...     3.8
# 1  What You Will Do:\n\nI. General Summary\n\nThe...     3.4
# 2  KnowBe4, Inc. is a high growth information sec...     4.8
# 3  *Organization and Job ID**\nJob ID: 310709\n\n...     3.8
# 4  Data Scientist\nAffinity Solutions / Marketing...     2.9
#
#                                  Company Name         Location  \
# 0                      Tecolote Research\n3.8  Albuquerque, NM
# 1  University of Maryland Medical System\n3.4    Linthicum, MD
# ...

# %%
data['seniority'] = data['Job Title'].apply(seniority)

# %%
data.head()
# Out:
#                    Job Title              Salary Estimate  \
# 0             Data Scientist   $53K-$91K (Glassdoor est.)
# 1  Healthcare Data Scientist  $63K-$112K (Glassdoor est.)
# 2             Data Scientist   $80K-$90K (Glassdoor est.)
# 3             Data Scientist   $56K-$97K (Glassdoor est.)
# 4             Data Scientist  $86K-$143K (Glassdoor est.)
#
#                                      Job Description  Rating  \
# 0  Data Scientist\nLocation: Albuquerque, NM\nEdu...     3.8
# 1  What You Will Do:\n\nI. General Summary\n\nThe...     3.4
# 2  KnowBe4, Inc. is a high growth information sec...     4.8
# 3  *Organization and Job ID**\nJob ID: 310709\n\n...     3.8
# 4  Data Scientist\nAffinity Solutions / Marketing...     2.9
#
#                                  Company Name         Location  \
# 0                      Tecolote Research\n3.8  Albuquerque, NM
# 1  University of Maryland Medical System\n3.4    Linthicum, MD
# ...

# %%
data.job_state.value_counts()
# Out:
#  CA             151
#  MA             103
#  NY              72
#  VA              41
#  IL              40
#  MD              35
#  PA              33
#  TX              28
#  NC              21
#  WA              21
#  NJ              17
#  FL              16
#  OH              14
#  TN              13
#  CO              11
#  DC              11
#  IN              10
#  WI              10
#  UT              10
#  MO               9
#  AZ               9
#  AL               8
#  DE               6
#  KY               6
#  GA               6
#  MI               6
#  CT               5
#  IA               5
#  NE               4
#  LA               4
#  OR               4
#  KS               3
#  NM               3
#  MN               2
#  ID               2
#  SC               1
#  Los Angeles      1
#  RI               1
# Name: job_state, dtype: int64

# %%
#Fix LA state
data['job_state']= data.job_state.apply(lambda x: x.strip() if x.strip().lower() != 'los angeles' else 'CA')
data.job_state.value_counts()
# Out:
# CA    152
# MA    103
# NY     72
# VA     41
# IL     40
# MD     35
# PA     33
# TX     28
# WA     21
# NC     21
# NJ     17
# FL     16
# OH     14
# TN     13
# DC     11
# CO     11
# IN     10
# WI     10
# UT     10
# MO      9
# AZ      9
# AL      8
# KY      6
# MI      6
# GA      6
# DE      6
# IA      5
# CT      5
# NE      4
# OR      4
# LA      4
# KS      3
# NM      3
# MN      2
# ID      2
# RI      1
# SC      1
# Name: job_state, dtype: int64

# %%
#The lenght of the job description
data['description_lenght'] = data['Job Description'].apply(lambda x: len(x))

# %%
data.head()
# Out:
#                    Job Title              Salary Estimate  \
# 0             Data Scientist   $53K-$91K (Glassdoor est.)
# 1  Healthcare Data Scientist  $63K-$112K (Glassdoor est.)
# 2             Data Scientist   $80K-$90K (Glassdoor est.)
# 3             Data Scientist   $56K-$97K (Glassdoor est.)
# 4             Data Scientist  $86K-$143K (Glassdoor est.)
#
#                                      Job Description  Rating  \
# 0  Data Scientist\nLocation: Albuquerque, NM\nEdu...     3.8
# 1  What You Will Do:\n\nI. General Summary\n\nThe...     3.4
# 2  KnowBe4, Inc. is a high growth information sec...     4.8
# 3  *Organization and Job ID**\nJob ID: 310709\n\n...     3.8
# 4  Data Scientist\nAffinity Solutions / Marketing...     2.9
#
#                                  Company Name         Location  \
# 0                      Tecolote Research\n3.8  Albuquerque, NM
# 1  University of Maryland Medical System\n3.4    Linthicum, MD
# ...

# %%
#Competitor count
data['number_of_competitors'] = data['Competitors'].apply(lambda x:len(x.split(',')) if x!='-1' else 0)

# %%
data['number_of_competitors']
# Out:
# 0      0
# 1      0
# 2      0
# 3      3
# 4      3
#       ..
# 737    3
# 738    3
# 739    0
# 740    0
# 741    0
# Name: number_of_competitors, Length: 742, dtype: int64

# %%
#hourly to annual wage
data['minimum_salary'] = data.apply(lambda x: x.minimum_salary*2 if x.hourly ==1 else x.minimum_salary, axis =1)
data['maximum_salary'] = data.apply(lambda x: x.maximum_salary*2 if x.hourly ==1 else x.maximum_salary, axis =1)

# %%
data.columns
# Out:
# Index(['Job Title', 'Salary Estimate', 'Job Description', 'Rating',
#        'Company Name', 'Location', 'Headquarters', 'Size', 'Founded',
#        'Type of ownership', 'Industry', 'Sector', 'Revenue', 'Competitors',
#        'hourly', 'employer_provided', 'minimum_salary', 'maximum_salary',
#        'average_salary', 'company_name_txt', 'job_state', 'same_state',
#        'Age of the company', 'Python', 'R_studio', 'spark', 'aws', 'excel',
#        'title_simplified', 'seniority', 'description_lenght',
#        'number_of_competitors'],
#       dtype='object')

# %%
data[data.hourly ==1][['hourly','minimum_salary','maximum_salary']]
# Out:
#      hourly  minimum_salary  maximum_salary
# 165       1              34              48
# 177       1              42              68
# 197       1              36              50
# 202       1              42              68
# 210       1              30              50
# 246       1              34              48
# 271       1              42              68
# 337       1              36              50
# 345       1              48              78
# 357       1              42              68
# 363       1              50              56
# 408       1              42              58
# 409       1              20              34
# 492       1              36              50
# 509       1              48              78
# 533       1              42              68
# 542       1              50              56
# 617       1              42              58
# 618       1              20              34
# 645       1              54              94
# ...

# %%
data.company_name_txt
# Out:
# 0                          Tecolote Research\n
# 1      University of Maryland Medical System\n
# 2                                    KnowBe4\n
# 3                                       PNNL\n
# 4                         Affinity Solutions\n
#                         ...
# 737                                      GSK\n
# 738                               Eventbrite\n
# 739           Software Engineering Institute\n
# 740                             Numeric, LLC\n
# 741             Riverside Research Institute\n
# Name: company_name_txt, Length: 742, dtype: object

# %%
#remove the '\n' from the company name
data['company_name_txt']= data.company_name_txt.apply(lambda x:x.replace('\n',''))

# %%
data['company_name_txt']
# Out:
# 0                          Tecolote Research
# 1      University of Maryland Medical System
# 2                                    KnowBe4
# 3                                       PNNL
# 4                         Affinity Solutions
#                        ...
# 737                                      GSK
# 738                               Eventbrite
# 739           Software Engineering Institute
# 740                             Numeric, LLC
# 741             Riverside Research Institute
# Name: company_name_txt, Length: 742, dtype: object

# %%
data.Rating.hist()
# Out:
# <AxesSubplot:>

# %%
data.average_salary.hist()
# Out:
# <AxesSubplot:>

# %%
data.boxplot(column='Rating')
# Out:
# <AxesSubplot:>

# %%
data.boxplot(column='average_salary')
# Out:
# <AxesSubplot:>

# %%
data[['Age of the company','average_salary','Rating','description_lenght']].corr()
# Out:
#                     Age of the company  average_salary    Rating  \
# Age of the company            1.000000        0.019574  0.023162
# average_salary                0.019574        1.000000  0.013492
# Rating                        0.023162        0.013492  1.000000
# description_lenght            0.164188        0.078808 -0.012281
#
#                     description_lenght
# Age of the company            0.164188
# average_salary                0.078808
# Rating                       -0.012281
# description_lenght            1.000000

# %%
cmap = sns.diverging_palette(220, 10, as_cmap=True)
sns.heatmap(data[['Age of the company','average_salary','Rating','description_lenght','number_of_competitors']].corr(),vmax=.3, center=0, cmap=cmap,
            square=True, linewidths=.5, cbar_kws={"shrink": .5})
# Out:
# <AxesSubplot:>

# %%
#plot the categorical variables
data_categorical = data[['Location', 'Headquarters', 'Size','Type of ownership', 'Industry', 'Sector', 'Revenue', 'company_name_txt', 'job_state','same_state', 'Python', 'R_studio',
       'spark', 'aws', 'excel', 'title_simplified', 'seniority']]

# %%
for i in data_categorical.columns:
    cat_num = data_categorical[i].value_counts()
    print("graph for %s: total = %d" % (i, len(cat_num)))
    chart = sns.barplot(x=cat_num.index, y=cat_num)
    chart.set_xticklabels(chart.get_xticklabels(), rotation=90)
    plt.show()
# Out:
# graph for Location: total = 200
# graph for Headquarters: total = 198
# graph for Size: total = 9
# graph for Type of ownership: total = 11
# graph for Industry: total = 60
# graph for Sector: total = 25
# graph for Revenue: total = 14
# graph for company_name_txt: total = 343
# graph for job_state: total = 37
# graph for same_state: total = 2
# graph for Python: total = 2
# graph for R_studio: total = 2
# graph for spark: total = 2
# graph for aws: total = 2
# graph for excel: total = 2
# graph for title_simplified: total = 7
# graph for seniority: total = 3

# %%
for i in data_categorical[['Location','Headquarters','company_name_txt']].columns:
    cat_num = data_categorical[i].value_counts()[:20]
    print("graph for %s: total = %d" % (i, len(cat_num)))
    chart = sns.barplot(x=cat_num.index, y=cat_num)
    chart.set_xticklabels(chart.get_xticklabels(), rotation=90)
    plt.show()
# Out:
# graph for Location: total = 20
# graph for Headquarters: total = 20
# graph for company_name_txt: total = 20

# %%
# the pay for the different jobs
pd.pivot_table(data,index='title_simplified',values='average_salary')
# Out:
#                   average_salary
# title_simplified
# analyst                65.857843
# data engineer         105.403361
# data scientist        117.564516
# director              168.607143
# manager                84.022727
# mle                   126.431818
# na                     84.853261

# %%
#the pay for the different jobs, in different seniority levels
pd.pivot_table(data,index=['title_simplified','seniority'],values='average_salary')
# Out:
#                             average_salary
# title_simplified seniority
# analyst          jr              56.500000
#                  na              61.155405
#                  senior          79.092593
# data engineer    na              96.701220
#                  senior         124.689189
# data scientist   jr             106.500000
#                  na             107.043011
#                  senior         138.956522
# director         na             168.607143
# manager          na              84.022727
# mle              na             119.133333
#                  senior         142.071429
# na               na              73.988189
#                  senior         109.061404

# %%
#Pay by state
pd.pivot_table(data[data.title_simplified == 'data scientist'], index = 'job_state', values = 'average_salary').sort_values('average_salary', ascending = False)
# Out:
#            average_salary
# job_state
# DC             149.000000
# CA             142.522059
# UT             140.500000
# MO             127.666667
# IL             117.233333
# NC             117.000000
# NY             115.250000
# MA             113.750000
# WI             113.500000
# PA             113.333333
# MD             109.115385
# CO             108.666667
# VA             108.416667
# NJ             106.875000
# MI             106.625000
# OH             105.285714
# TX             100.730769
# WA              99.764706
# OR              98.500000
# FL              97.357143
# TN              96.000000
# IN              84.500000
# KY              84.000000
# CT              84.000000
# GA              81.333333
# NM              74.333333
# AZ              69.500000

# %%
pd.options.display.max_rows
pd.set_option('display.max_rows', None)
pd.pivot_table(data, index = ['job_state','title_simplified'], values = 'average_salary', aggfunc = 'count').sort_values('job_state', ascending = False)
# Out:
#                             average_salary
# job_state title_simplified
# WI        na                             4
#           data scientist                 3
#           analyst                        3
# WA        na                             1
#           data scientist                17
#           analyst                        3
# VA        na                             5
#           mle                            2
#           data scientist                18
#           data engineer                 10
#           analyst                        6
# UT        data engineer                  3
#           analyst                        4
#           data scientist                 3
# TX        na                             7
#           data scientist                13
#           data engineer                  8
# TN        data scientist                 1
#           data engineer                 10
#           analyst                        2
# ...

# %%
#salary as a function of:
data_pivots = data[['Rating', 'Industry', 'Sector', 'Revenue', 'number_of_competitors', 'hourly', 'employer_provided', 'Python', 'R_studio', 'spark', 'aws', 'excel', 'Type of ownership','average_salary']]

# %%
data.columns
# Out:
# Index(['Job Title', 'Salary Estimate', 'Job Description', 'Rating',
#        'Company Name', 'Location', 'Headquarters', 'Size', 'Founded',
#        'Type of ownership', 'Industry', 'Sector', 'Revenue', 'Competitors',
#        'hourly', 'employer_provided', 'minimum_salary', 'maximum_salary',
#        'average_salary', 'company_name_txt', 'job_state', 'same_state',
#        'Age of the company', 'Python', 'R_studio', 'spark', 'aws', 'excel',
#        'title_simplified', 'seniority', 'description_lenght',
#        'number_of_competitors'],
#       dtype='object')

# %%
for i in data_pivots.columns:
    print(i)
    print(pd.pivot_table(data_pivots,index =i, values = 'average_salary').sort_values('average_salary', ascending = False))
# Out:
# Rating
#         average_salary
# Rating
# -1.0        136.181818
#  5.0        134.700000
#  2.5        120.000000
#  4.5        117.714286
#  4.1        116.368421
#  3.9        113.071429
#  2.6        109.083333
#  4.4        108.606061
#  3.2        105.500000
#  4.0        105.340426
#  3.5        104.897959
#  3.7        104.131148
#  4.7        103.983871
#  4.3        102.468750
#  3.3        101.858974
#  4.2        100.442308
#  2.2         97.750000
#  4.6         97.250000
#  3.8         96.811475
#  2.1         95.900000
#  3.4         93.011364
#  1.9         87.500000
#  3.1         86.580000
#  3.0         85.588235
#  3.6         85.467391
#  2.8         83.928571
#  2.7         83.250000
#  2.3         81.500000
#  2.9         81.138889
#  4.8         80.277778
#  2.4         60.214286
# Industry
#                                           average_salary
# Industry
# Other Retail Stores                           163.500000
# ...

# %%
data.to_csv('eda_data_cleaned.csv')
